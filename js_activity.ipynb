# %% [markdown]
# <a href="https://colab.research.google.com/github/forre5t/it612/blob/main/js_activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
#
# let x = 5;
#
# let y = 10;
#
# let sum = x + y;
#
# console.log(`Sum is ${sum}`);
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# Sum is 15
